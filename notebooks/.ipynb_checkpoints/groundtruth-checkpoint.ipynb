# %% [markdown]
# # Ground truth generation
# This Jupyter Notebook explains the process by which ground truths are extracted from both the Muscima and the Deepscores dataset. Thus, it also illustrates the process that will be used for inference.

# %%
import sys
# Including the source dir for relevant modules
sys.path.insert(0, '../src/autoscore/')

import cv2 as cv
import torch
from matplotlib import pyplot as plt

from os import listdir
from os.path import isfile, join

from musicdata import *

deepscores_fn = '../../data/DEEPSCORES/images_png/'
deepscores_gt_fn = '../../data/DEEPSCORES/xml_annotations/'
muscima_fn = '../../data/MUSCIMA/CvcMuscima-Distortions/'
muscima_gt_fn = '../../data/MUSCIMA/v1.0/data/cropobjects_manual/'

# %% [markdown]
# All the output from the deepscores.cc and muscima.cc binaries are stored in the `/datasets` directory. The output is in xml format and it describes the staff lines in the image.

# %%
'''
Parsing all the staff description xml files for both datasets that were 
generated by deepscores.cc and muscima.cc binaries
'''
artificial_files = [f for f in listdir(ARTIFICIAL_FN) if isfile(join(ARTIFICIAL_FN, f))]
handwritten_files = [f for f in listdir(HANDWRITTEN_FN) if isfile(join(HANDWRITTEN_FN, f))]

artificial_files = [get_music_file_from_xml(join(ARTIFICIAL_FN, f)) for f in artificial_files]
handwritten_files = [get_music_file_from_xml(join(HANDWRITTEN_FN, f)) for f in handwritten_files]

# %% [markdown]
# The Deepscores dataset's groundtruth is parsed and all the symbols that are polled a minimum amount of time will be kept. This number is currently set to 200 samples.

# %%
artificial_glyphs_per_score = []
deepscores_content = dict()
for music_file in artificial_files: 
    glyph_list = deepscores_score_ground_truth(music_file.filename, deepscores_gt_fn)
    artificial_glyphs_per_score.append(glyph_list)
    
for glyphs_in_score in artificial_glyphs_per_score:
    for glyph in glyphs_in_score:
        if glyph.name not in deepscores_content:
            deepscores_content[glyph.name] = 1
        else:
            deepscores_content[glyph.name] += 1
    
for score, music_file in enumerate(artificial_files):
    music_file.position_glyphs(artificial_glyphs_per_score[score], deepscores_content)

# %%
# Visualizing the result on one score
# %matplotlib inline

test_filename = artificial_files[0].filename
img = cv.imread(join(deepscores_fn, test_filename), cv.CV_8UC1)
img = artificial_files[0].visualize(img, divs=False)
    
plt.figure(figsize=(40,40))
plt.imshow(img / 255.0);
plt.axis('off')
plt.title('Test image of dataset ground truth on {0}'.format(test_filename),
         fontsize=20);

# %% [markdown]
# The process is repeated for the Muscima dataset. The difference is that the Muscima dataset has annotation for only 140 music scores. Therefore, to augment the dataset, the ideal annotation is combined with some distortions for a total of 980 scores.

# %%
sorted_handwritten_files = sort_by_writers(handwritten_files)
muscima_content = dict()
handwritten_glyphs_per_score = []
for music_file in sorted_handwritten_files: 
    filename = 'CVC-MUSCIMA_W-' + str(music_file[0]).zfill(2) + '_N-' + \
                str(music_file[1]).zfill(2) + '_D-ideal.xml'
    handwritten_glyphs_per_score.append(muscima_score_ground_truth(filename, muscima_gt_fn))

for glyphs_in_score in handwritten_glyphs_per_score:
    for glyph in glyphs_in_score:
        if glyph.name not in muscima_content:
            muscima_content[glyph.name] = 1
        else:
            muscima_content[glyph.name] += 1    

for i, (writer, page) in enumerate(sorted_handwritten_files):
    distorsions = sorted_handwritten_files[(writer, page)]
    for file in distorsions:
        file.position_glyphs(handwritten_glyphs_per_score[i], muscima_content)

# %%
plt.figure(figsize=(40,40))

file = sorted_handwritten_files[list(sorted_handwritten_files.keys())[0]][0]
img = cv.imread(join(muscima_fn, file.filename), cv.CV_8UC1)
_, img = cv.threshold(img, 128, 255, cv.THRESH_BINARY_INV)
img = file.visualize(img, divs=False, labels=True)
plt.axis('off')
plt.imshow(img / 255.0);
plt.title('Test image of dataset ground truth on {0}'.format(file.filename),
         fontsize=20);

# %%
# Printing all the labels and their count across all the datasets
for glyph_name in deepscores_content:
    print('{0} : {1}'.format(glyph_name, deepscores_content[glyph_name]))
print('----------------------------------------------------')
for glyph_name in muscima_content:
    print('{0} : {1}'.format(glyph_name, muscima_content[glyph_name]))
# Out:
# augmentationDot : 1952
# noteheadBlack : 25360
# noteheadHalf : 1907
# timeSig3 : 44
# timeSig4 : 295
# keySharp : 1074
# gClef : 1285
# repeatDot : 200
# tuplet3 : 231
# ornamentTrill : 4
# fClef : 676
# articStaccatoAbove : 420
# dynamicForte : 63
# dynamicMF : 60
# flag8thDown : 768
# articMarcatoAbove : 39
# rest8th : 1185
# articMarcatoBelow : 13
# articTenutoAbove : 26
# dynamicPiano : 38
# dynamicPPP : 1
# dynamicFFF : 19
# flag8thUp : 782
# accidentalNatural : 472
# accidentalFlat : 303
# keyFlat : 1543
# brace : 258
# rest16th : 405
# flag16thDown : 176
# flag16thUp : 127
# noteheadWhole : 591
# restWhole : 1704
# clef8 : 135
# clef15 : 7
# restQuarter : 905
# accidentalSharp : 587
# restHalf : 403
# unpitchedPercussionClef1 : 60
# articStaccatoBelow : 250
# rest32nd : 248
# timeSigCommon : 157
# fingering3 : 35
# fingering1 : 33
# fingering4 : 26
# fingering2 : 43
# fingering5 : 25
# dynamicFF : 33
# keyNatural : 13
# dynamicPP : 18
# fermataAbove : 34
# cClefAlto : 45
# restHBar : 30
# dynamicMP : 23
# articAccentAbove : 92
# gClefChange : 13
# fClefChange : 12
# articAccentBelow : 42
# flag32ndDown : 16
# rest64th : 120
# flag64thUp : 54
# keyboardPedalUp : 52
# flag64thDown : 6
# timeSig6 : 4
# timeSig8 : 15
# timeSig2 : 39
# arpeggiato : 4
# coda : 1
# tuplet6 : 6
# noteheadBlackSmall : 16
# graceNoteAcciaccaturaStemUp : 6
# accidentalSharpSmall : 2
# flag32ndUp : 17
# accidentalDoubleSharp : 39
# keyboardPedalPed : 14
# dynamicSforzato : 5
# graceNoteAppoggiaturaStemUp : 7
# timeSig5 : 3
# stringsUpBow : 3
# flag128thDown : 2
# rest128th : 2
# cClefTenor : 1
# caesura : 2
# graceNoteAppoggiaturaStemDown : 1
# timeSig1 : 5
# ----------------------------------------------------
# g-clef : 402
# sharp : 2068
# 8th_rest : 1134
# quarter_rest : 803
# notehead-full : 21333
# stem : 21416
# 8th_flag : 2200
# beam : 6593
# letter_p : 511
# letter_f : 508
# letter_e : 443
# letter_s : 329
# letter_x : 8
# letter_r : 385
# letter_i : 95
# letter_o : 326
# letter_d : 164
# letter_n : 93
# letter_l : 87
# letter_M : 56
# slur : 2602
# tie : 704
# thin_barline : 3332
# numeral_2 : 34
# numeral_3 : 327
# numeral_4 : 139
# flat : 1112
# natural : 1090
# 16th_rest : 436
# hairpin-cresc. : 224
# letter_u : 50
# letter_t : 272
# letter_R : 33
# letter_P : 79
# letter_z : 35
# letter_a : 84
# ledger_line : 6848
# other-dot : 197
# duration-dot : 2067
# staccato-dot : 1385
# tenuto : 146
# key_signature : 695
# time_signature : 192
# tuple : 244
# other_text : 271
# tempo_text : 116
# dynamics_text : 682
# 16th_flag : 499
# notehead-empty : 1668
# grace-notehead-full : 348
# repeat_measure : 16
# whole_rest : 153
# multi-measure_rest : 44
# fermata : 35
# breath_mark : 13
# measure_separator : 2854
# hairpin-decr. : 276
# f-clef : 284
# letter_L : 10
# letter_T : 16
# letter_m : 142
# letter_c : 224
# letter_j : 7
# letter_V : 6
# letter_v : 11
# whole-time_mark : 27
# letter_b : 7
# numeral_5 : 7
# numeral_7 : 14
# numeral_8 : 29
# accent : 201
# numeral_6 : 26
# c-clef : 189
# tuple_bracket/line : 51
# multiple-note_tremolo : 112
# half_rest : 216
# staff_grouping : 191
# multi-staff_bracket : 51
# repeat-dot : 266
# numeral_1 : 12
# horizontal_spanner : 12
# repeat : 84
# other_numeric_sign : 12
# volta : 12
# double_sharp : 39
# multi-staff_brace : 113
# thick_barline : 42
# letter_g : 21
# trill : 179
# trill_"wobble" : 23
# ornament(s) : 75
# arpeggio_"wobble" : 21
# letter_A : 12
# unclassified : 25
# grace_strikethrough : 74
# instrument_specific : 47
# dotted_horizontal_spanner : 8
# glissando : 26
# letter_F : 19
# numeral_0 : 6
# letter_other : 36
# transposition_text : 3
# curved-line_(tie-or-slur) : 1
# other-clef : 5
# letter_C : 2
# letter_S : 1
# letter_E : 1

# %% [markdown]
# Then, for both datasets, a kernel of specified size is moved along the staff lines and the symbols that have at least 80% of the area of their bounding box inside that kernel will be kept. The result is a set of images that contain at least one glyph. For the case where two glyph are in the same image, the label of the most polled one is used.
#
# In music transcription, there is usually only one symbol vertically unless there are chords, multiple sharps/flats or staccatos. Since the goal of auto-score is mainly tablature generation, only the pitch will matter. Therefore, whenever a sharp, a flat or a note is found, the kernel is then examined vertically to find the positions of said glyphs.

# %%
def plot_glyphs(X, y, size=6):
    fig, axes = plt.subplots(size, size, figsize=(20,20))
    count = 0
    for (x, label) in zip(X, y):
        if label == 'None':
            continue
        if count == len(axes)**2:
            break
        idx = count % len(axes), count // len(axes)
        axes[idx].imshow(x / 255.0, cmap='gray')
        axes[idx].set_title(label)
        count += 1

# Displaying the samples for training in a single image (computer generated)
file = artificial_files[0]
img = cv.imread(join(deepscores_fn, file.filename), cv.CV_8UC1)
X, y = file.extract_training_data(img, deepscores_content)
plot_glyphs(X, y)

# %%
# Displaying the samples for training in a single image (computer generated)
file = handwritten_files[0]
img = cv.imread(join(muscima_fn, file.filename), cv.CV_8UC1)
X, y = file.extract_training_data(img, muscima_content)
plot_glyphs(X, y)
