# %% [markdown]
# # Ground truth generation
# This Jupyter Notebook explains the process by which ground truths are extracted from both the Muscima and the Deepscores dataset. Thus, it also illustrates the process that will be used for inference.

# %%
import sys
sys.path.insert(0, '../src/autoscore/')
import cv2 as cv
import torch
from matplotlib import pyplot as plt

from os import listdir
from os.path import isfile, join

# %% [markdown]
# All the output from the deepscores.cc and muscima.cc binaries are stored in the `/datasets` directory. The output is in xml format and it describes the staff lines in the image.

# %%
'''
Parsing all the staff description xml files for both datasets that were 
generated by deepscores.cc and muscima.cc binaries
'''
from datasets import staff_xml

artificial_fn = '../datasets/Artificial/'
artificial_files = [f for f in listdir(artificial_fn) if isfile(join(artificial_fn, f))]
handwritten_fn = '../datasets/Handwritten/'
handwritten_files = [f for f in listdir(handwritten_fn) if isfile(join(handwritten_fn, f))]

artificial_files = [staff_xml(join(artificial_fn, f)) for f in artificial_files]
handwritten_files = [staff_xml(join(handwritten_fn, f)) for f in handwritten_files]

# %% [markdown]
# The Deepscores dataset's groundtruth is parsed and all the symbols that are polled a minimum amount of time will be kept. This number is currently set to 200 samples.

# %%
# Parsing deepscores dataset groundtruths
from datasets import deepscores_gt, muscima_gt

deepscores_fn = '../../auto-score-datasets/images_png/'
deepscores_gt_fn = '../../auto-score-datasets/xml_annotations/'
muscima_fn = '../../auto-score-datasets/CvcMuscima-Distortions/'
muscima_gt_fn = '../../auto-score-datasets/v1.0/data/cropobjects_manual/'

glyphs = []
deepscores_dict = dict()
for music_file in artificial_files: 
    glyph_list = deepscores_gt(music_file.filename, deepscores_gt_fn, deepscores_dict)
    glyphs.append(glyph_list)
    
for idx, music_file in enumerate(artificial_files):
    music_file.compute_kernel()
    music_file.locate(glyphs[idx], deepscores_dict)

# %%
# Visualizing the result
# %matplotlib inline

test_filename = artificial_files[0].filename
img = cv.imread(join(deepscores_fn, test_filename), cv.CV_8UC1)
img = artificial_files[0].visualize(img, divs=False)
    
plt.figure(figsize=(40,40))
plt.imshow(img / 255.0);
plt.axis('off')
plt.title('Test image of dataset ground truth on {0}'.format(test_filename),
         fontsize=20);

# %% [markdown]
# The process is repeated for the Muscima dataset. The difference is that the Muscima dataset has annotation for only 140 music scores. Therefore, to augment the dataset, the ideal annotation is combined with some distortions for a total of 980 scores.

# %%
from datasets import sort_by_writers

sorted_handwritten_files = sort_by_writers(handwritten_files)
muscima_dict = dict()
glyphs = []
for music_file in sorted_handwritten_files: 
    filename = 'CVC-MUSCIMA_W-' + str(music_file[0]).zfill(2) + '_N-' + str(music_file[1]).zfill(2) + '_D-ideal.xml'
    glyphs.append(muscima_gt(filename, muscima_gt_fn, muscima_dict))
    
for idx, music_file in enumerate(sorted_handwritten_files):
    # Processing each distortion individually
    for file in sorted_handwritten_files[music_file]:
        file.compute_kernel()
        file.locate(glyphs[idx], muscima_dict)

# %%
plt.figure(figsize=(40,40))

file = sorted_handwritten_files[list(sorted_handwritten_files.keys())[0]][0]
img = cv.imread(join(muscima_fn, file.filename), cv.CV_8UC1)
_, img = cv.threshold(img, 128, 255, cv.THRESH_BINARY_INV)
img = file.visualize(img, divs=False, labels=True)
plt.axis('off')
plt.imshow(img / 255.0);
plt.title('Test image of dataset ground truth on {0}'.format(file.filename),
         fontsize=20);

# %%
# Printing all the labels and their count across all the datasets
for key in deepscores_dict:
    print('{0} : {1}'.format(key, deepscores_dict[key]))
print('----------------------------------------------------')
for key in muscima_dict:
    print('{0} : {1}'.format(key, muscima_dict[key]))
# Out:
# accidentalNatural : 5995
# noteheadBlack : 307309
# rest8th : 13575
# flag8thDown : 10049
# accidentalSharp : 8243
# augmentationDot : 19606
# accidentalFlat : 4963
# flag8thUp : 8335
# fClef : 7739
# keyFlat : 18331
# brace : 3875
# gClef : 14753
# restQuarter : 10316
# restWhole : 18511
# dynamicForte : 770
# fermataBelow : 45
# rest64th : 1316
# articStaccatoBelow : 4151
# articStaccatoAbove : 5068
# rest32nd : 1538
# flag32ndUp : 201
# rest16th : 5938
# clef8 : 1858
# keySharp : 16332
# unpitchedPercussionClef1 : 666
# timeSig3 : 479
# timeSig4 : 3357
# repeatDot : 2686
# noteheadHalf : 23360
# ornamentMordent : 23
# restHalf : 3516
# flag16thDown : 1987
# noteheadWhole : 7421
# cClefAlto : 575
# dynamicFF : 302
# dynamicMF : 524
# dynamicMP : 441
# dynamicPiano : 488
# fClefChange : 120
# gClefChange : 123
# dynamicFortePiano : 14
# ornamentTrill : 94
# articAccentBelow : 945
# articAccentAbove : 1485
# dynamicSforzando1 : 97
# timeSigCommon : 1238
# timeSig1 : 138
# timeSig2 : 380
# timeSig8 : 364
# flag16thUp : 1485
# accidentalNaturalSmall : 7
# graceNoteAppoggiaturaStemUp : 131
# noteheadBlackSmall : 410
# clef15 : 52
# tuplet3 : 3284
# accidentalSharpSmall : 14
# accidentalDoubleSharp : 333
# flag64thUp : 95
# flag32ndDown : 238
# flag64thDown : 38
# graceNoteAcciaccaturaStemUp : 100
# fingering1 : 120
# fingering3 : 110
# fingering4 : 124
# fingering5 : 10
# fingering2 : 120
# articTenutoAbove : 251
# keyboardPedalUp : 433
# arpeggiato : 230
# dynamicPP : 145
# restHBar : 435
# fermataAbove : 328
# dynamicFFF : 110
# keyNatural : 359
# caesura : 93
# fingering0 : 95
# graceNoteAcciaccaturaStemDown : 1
# timeSig6 : 307
# tuplet6 : 170
# articMarcatoAbove : 182
# keyboardPedalPed : 63
# dynamicPPP : 8
# timeSig7 : 21
# articTenutoBelow : 182
# noteheadDoubleWhole : 30
# timeSig5 : 65
# stringsDownBow : 117
# stringsUpBow : 170
# segno : 7
# cClefTenor : 44
# articStaccatissimoAbove : 41
# cClefAltoChange : 3
# cClefTenorChange : 4
# articMarcatoBelow : 175
# rest128th : 40
# accidentalDoubleFlat : 61
# accidentalFlatSmall : 8
# timeSig9 : 14
# dynamicSforzato : 12
# dynamicFFFF : 8
# timeSigCutCommon : 20
# graceNoteAppoggiaturaStemDown : 13
# ornamentTurn : 1
# dynamicMezzo : 1
# coda : 2
# flag128thDown : 1
# articStaccatissimoBelow : 4
# ----------------------------------------------------
# notehead-full : 21333
# notehead-empty : 1668
# stem : 21416
# flat : 1112
# key_signature : 695
# duration-dot : 2067
# beam : 6593
# natural : 1090
# letter_r : 385
# letter_other : 36
# 8th_rest : 1134
# trill : 179
# 8th_flag : 2200
# ledger_line : 6848
# tie : 704
# 16th_flag : 499
# thin_barline : 3332
# g-clef : 402
# f-clef : 284
# c-clef : 189
# multi-staff_brace : 113
# multi-staff_bracket : 51
# letter_T : 16
# letter_t : 272
# staff_grouping : 191
# measure_separator : 2854
# sharp : 2068
# 16th_rest : 436
# thick_barline : 42
# repeat-dot : 266
# repeat : 84
# slur : 2602
# numeral_3 : 327
# numeral_4 : 139
# time_signature : 192
# unclassified : 25
# multiple-note_tremolo : 112
# staccato-dot : 1385
# accent : 201
# hairpin-decr. : 276
# quarter_rest : 803
# half_rest : 216
# letter_f : 508
# dynamics_text : 682
# whole-time_mark : 27
# numeral_7 : 14
# numeral_8 : 29
# numeral_5 : 7
# numeral_6 : 26
# fermata : 35
# letter_m : 142
# letter_o : 326
# letter_d : 164
# letter_e : 443
# tempo_text : 116
# letter_p : 511
# letter_s : 329
# letter_a : 84
# letter_l : 87
# other-dot : 197
# letter_n : 93
# letter_z : 35
# letter_j : 7
# letter_u : 50
# letter_c : 224
# letter_b : 7
# letter_i : 95
# other_text : 271
# tuple : 244
# hairpin-cresc. : 224
# breath_mark : 13
# tuple_bracket/line : 51
# numeral_2 : 34
# letter_M : 56
# instrument_specific : 47
# dotted_horizontal_spanner : 8
# grace-notehead-full : 348
# grace_strikethrough : 74
# whole_rest : 153
# arpeggio_"wobble" : 21
# horizontal_spanner : 12
# numeral_1 : 12
# other_numeric_sign : 12
# volta : 12
# double_sharp : 39
# letter_P : 79
# multi-measure_rest : 44
# letter_A : 12
# letter_g : 21
# glissando : 26
# letter_R : 33
# letter_x : 8
# numeral_0 : 6
# repeat_measure : 16
# tenuto : 146
# transposition_text : 3
# trill_"wobble" : 23
# ornament(s) : 75
# letter_v : 11
# letter_L : 10
# letter_V : 6
# letter_F : 19
# curved-line_(tie-or-slur) : 1
# other-clef : 5
# letter_C : 2
# letter_S : 1
# letter_E : 1

# %% [markdown]
# Then, for both datasets, a kernel of specified size is moved along the staff lines and the symbols that have at least 80% of the area of their bounding box inside that kernel will be kept. The result is a set of images that contain at least one glyph. For the case where two glyph are in the same image, the label of the most polled one is used.
#
# In music transcription, there is usually only one symbol vertically unless there are chords, multiple sharps/flats or staccatos. Since the goal of auto-score is mainly tablature generation, only the pitch will matter. Therefore, whenever a sharp, a flat or a note is found, the kernel is then examined vertically to find the positions of said glyphs.

# %%
# Displaying the samples for training in a single image (computer generated)
file = artificial_files[0]
img = cv.imread(join(deepscores_fn, file.filename), cv.CV_8UC1)
samples = file.extract_samples(img, deepscores_dict)
print(len([sample for sample in samples if sample[1] != 'None']))
fig, axes = plt.subplots(6,6, figsize=(20,20))

i = 0
for sample in samples:
    if sample[1] == 'None':
        continue
    idx = i % len(axes), i // len(axes)
    axes[idx].imshow(sample[0] / 255.0, cmap='gray')
    axes[idx].set_title(sample[1])
    i += 1
    if i == len(axes)**2: 
        break
# Out:
# 284

# %%
# Displaying the samples for training in a single image (handwritten)
file = handwritten_files[0]
img = cv.imread(join(muscima_fn, file.filename), cv.CV_8UC1)
samples = file.extract_samples(img, muscima_dict, thresh=0.5)
print(len([sample for sample in samples if sample[1] != 'None']))
fig, axes = plt.subplots(6,6, figsize=(20,20))

i = 0
for sample in samples:
    if sample[1] == 'None':
        continue
    idx = i % len(axes), i // len(axes)
    axes[idx].imshow(sample[0] / 255.0, cmap='gray')
    axes[idx].set_title(sample[1])
    i += 1
    if i == len(axes)**2: 
        break
# Out:
# 319
